# %% [markdown]
# # **Análisis y seguimiento de delitos cometidos en Bucaramanga.**

# %%
#@title **Acceso al drive**
import os
from google.colab import drive
drive.mount('/content/drive')
os.chdir('/content/drive/My Drive/U/course-IA1/PROYECTO')
print(os.getcwd())
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/U/course-IA1/PROYECTO

# %%
#@title **Librerias**
from sklearn.datasets import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()
import collections
import operator
from collections import Counter
from sklearn.cluster import KMeans

# %%
#@title **Cargue del dataset**
os.chdir('/content/drive/My Drive/U/course-IA1/PROYECTO')
print(os.getcwd())
d =  pd.read_csv("Copia Delitos_en_Bucaramanga.csv")
print("\nTipo de dato d:", type(d))
print("columns and shape", d.columns, d.shape)
print("---------------- \n Display data \n----------------")
d.head(10)
# Out:
# /content/drive/My Drive/U/course-IA1/PROYECTO
#
# Tipo de dato d: <class 'pandas.core.frame.DataFrame'>
# columns and shape Index(['ORDEN', 'ARMAS_MEDIOS', 'BARRIOS_HECHO', 'LATITUD', 'LONGITUD', 'ZONA',
#        'NOM_COMUNA', 'ANO', 'MES', 'DIA', 'DIA_SEMANA', 'DESCRIPCION_CONDUCTA',
#        'CONDUCTA', 'CLASIFICACIONES DELITO', 'EDAD', 'CURSO_DE_VIDA',
#        'ESTADO_CIVIL_PERSONA', 'GENERO', 'MOVIL_AGRESOR', 'MOVIL_VICTIMA'],
#       dtype='object') (129768, 20)
# ----------------
#  Display data
# ----------------
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (3,4) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    ORDEN                 ARMAS_MEDIOS  ... MOVIL_AGRESOR MOVIL_VICTIMA
# 0      1  ARMA BLANCA / CORTOPUNZANTE  ...         A PIE         A PIE
# 1      2  ARMA BLANCA / CORTOPUNZANTE  ...         A PIE         A PIE
# 2      3  ARMA BLANCA / CORTOPUNZANTE  ...         A PIE         A PIE
# 3      4  ARMA BLANCA / CORTOPUNZANTE  ...         A PIE         A PIE
# 4      5  ARMA BLANCA / CORTOPUNZANTE  ...         A PIE         A PIE
# 5      6  ARMA BLANCA / CORTOPUNZANTE  ...         A PIE         A PIE
# 6      7  ARMA BLANCA / CORTOPUNZANTE  ...         A PIE         A PIE
# 7      8  ARMA BLANCA / CORTOPUNZANTE  ...         A PIE         A PIE
# 8      9  ARMA BLANCA / CORTOPUNZANTE  ...         A PIE         A PIE
# 9     10  ARMA BLANCA / CORTOPUNZANTE  ...         A PIE         A PIE
#
# [10 rows x 20 columns]

# %%
#@title **Corrección de datos, estableciendo un estandar.**

#Corrección de datos
d=d.rename(columns={'CLASIFICACIONES DELITO':'CLASIFICACIONES_DELITO'})
d.loc[d.DIA_SEMANA=='01. lunes','DIA_SEMANA']='01. Lunes'
d.loc[d.DIA_SEMANA=='02. martes','DIA_SEMANA']='02. Martes'
d.loc[d.DIA_SEMANA=='03. miércoles','DIA_SEMANA']='03. Miércoles'
d.loc[d.DIA_SEMANA=='04. jueves','DIA_SEMANA']='04. Jueves'
d.loc[d.DIA_SEMANA=='05. viernes','DIA_SEMANA']='05. Viernes'
d.loc[d.DIA_SEMANA=='06. sábado','DIA_SEMANA']='06. Sábado'
d.loc[d.NOM_COMUNA=='01. norte','NOM_COMUNA']='01. Norte'
d.loc[d.EDAD=='NO REPORTA','EDAD']='0'
d.loc[d.EDAD=='No reporta','EDAD']='0'
d.loc[d.EDAD=='No Reporta','EDAD']='0'
d.loc[d.EDAD=='-','EDAD']='0'
d.loc[d.ARMAS_MEDIOS=='-','ARMAS_MEDIOS']='No Reporta'
d.loc[d.ARMAS_MEDIOS=='NO REPORTADO','ARMAS_MEDIOS']='No Reporta'
d.loc[d.NOM_COMUNA=='corregimiento 1', 'NOM_COMUNA']='Corregimiento 1'
d.loc[d.NOM_COMUNA=='corregimiento 2', 'NOM_COMUNA']='Corregimiento 2'
d.loc[d.NOM_COMUNA=='corregimiento 3', 'NOM_COMUNA']='Corregimiento 3'
d.loc[d.NOM_COMUNA=='sin informacion', 'NOM_COMUNA']='Sin informacion'
d.loc[d.CONDUCTA=='-','CONDUCTA']='No Reporta'
d.loc[d.CONDUCTA=='<','CONDUCTA']='No Reporta'
d.loc[d.CONDUCTA=='No Reporta','CONDUCTA']='No Reporta'
d = d[d['CONDUCTA'].notna()]
d.loc[d.CURSO_DE_VIDA=='No Reporta','CURSO_DE_VIDA']='No Reporta'
d.loc[d.CURSO_DE_VIDA=='00. NO REPORTA','CURSO_DE_VIDA']='No Reporta'
d.loc[d.CURSO_DE_VIDA=='01. Primera Infancia','CURSO_DE_VIDA']='01. Primera infancia'
d.loc[d.CURSO_DE_VIDA=='05. adultez','CURSO_DE_VIDA']='05. Adultez'
d.loc[d.CURSO_DE_VIDA=='06. Persona Mayor','CURSO_DE_VIDA']='06. Persona mayor'

#Convertir el tipo de dato de la columna edad de string a double
d['EDAD']=pd.to_numeric(d['EDAD'])

# %%
#@title **Eliminación de datos que no se van a usar**
indexNames = d[ d['NOM_COMUNA'] == 'Corregimiento 1' ].index
d.drop(indexNames , inplace=True)
indexNames = d[ d['NOM_COMUNA'] == 'Corregimiento 2' ].index
d.drop(indexNames , inplace=True)
indexNames = d[ d['NOM_COMUNA'] == 'Corregimiento 3' ].index
d.drop(indexNames , inplace=True)
indexNames = d[ d['NOM_COMUNA'] == 'Sin informacion' ].index
d.drop(indexNames , inplace=True)

# %%
#@title **Primera información**

plt.figure(figsize = (20, 10))
ax = plt.subplot(1,2,1)
d.hist('DIA', ax=ax);
plt.title("Cantidad de delitos según el día del mes")
plt.xlabel("Día del mes")
plt.ylabel("Cantidad de delitos")

ax = plt.subplot(1,2,2)
d.hist('ANO', ax=ax);
plt.title("Cantidad de delitos según el año")
plt.xlabel("Año")
plt.ylabel("Cantidad de delitos")



plt.show()

# %%
#Ranking cantidad de delitos por comunas
dictComunas=collections.Counter(d['NOM_COMUNA'])
rankingComunas = sorted(dictComunas.items(), key=operator.itemgetter(1), reverse=True)
print("\nVector Ranking de delitos por comuna:",rankingComunas)
# Out:
# Vector Ranking de delitos por comuna: [('03. San Francisco', 15219), ('15. Centro', 13222), ('13. Oriental', 12864), ('12. Cabecera del Llano', 12215), ('01. Norte', 12193), ('06. La Concordia', 9561), ('05. García Rovira', 8696), ('04. Occidental', 7430), ('10. Provenza', 6316), ('09. La Pedregosa', 4868), ('02. Nor Oriental', 4494), ('11. Sur', 4339), ('17. Mutis', 4063), ('08. Sur Occidente', 3307), ('14. Morrorico', 3152), ('07. La Ciudadela', 3092), ('16. Lagos del Cacique', 3077)]

# %%
#Grafico Ranking cantidad de delitos por comunas
x, y = zip(*rankingComunas) 
myColors=['g','b','y','r','b','g','b','y','r','b','g','b','y','r','b','g','b','y','r','b','g']
plt.figure(figsize=(20,10))
plt.bar(x, y, width=1, color=myColors)
plt.xticks(rotation=70)
plt.title('Ranking delitos por comunas en Bucaramanga')
plt.xlabel('Identificadores de comunas')
plt.ylabel('Cantidad de delitos')
plt.show()

# %%
#@title **Adición de la característica de población por comuna al dataset**
nom_comuna=pd.unique(d['NOM_COMUNA'])
nom_comuna=sorted(nom_comuna)
pob_comuna = [54183, 35035, 44662, 38191, 42092, 28143 , 28933, 18411, 16623, 32299, 28459, 33404, 52290, 22936, 8627, 15045, 26723 ]

d['POB_COMUNA']=np.nan
for i in range(len(pob_comuna)):
  d.loc[d.NOM_COMUNA==nom_comuna[i],'POB_COMUNA']=pob_comuna[i]

# %%
x, y = zip(*rankingComunas) 
n_delitos=[]
nom_com=[]
for i in range(len(x)):
  n_delitos.append(y[i])
  nom_com.append(x[i])
d_comunas=pd.DataFrame({'NOM_COMUNAS':nom_com, 'N_DELITOS':n_delitos,'POB_COMUNAS':pob_comuna})

# %%
#Tasa de delito por comuna
tasa=(d_comunas['N_DELITOS']/d_comunas['POB_COMUNAS'])*100
d_comunas=d_comunas.assign(TASA_DELITOS=tasa)
d_comunas = d_comunas.sort_values('TASA_DELITOS', ascending=False)
d_comunas.head(17)
# Out:
#                NOM_COMUNAS  N_DELITOS  POB_COMUNAS  TASA_DELITOS
# 7           04. Occidental       7430        18411     40.356309
# 8             10. Provenza       6316        16623     37.995548
# 1               15. Centro      13222        35035     37.739403
# 14           14. Morrorico       3152         8627     36.536455
# 5         06. La Concordia       9561        28143     33.972924
# 3   12. Cabecera del Llano      12215        38191     31.983975
# 6        05. García Rovira       8696        28933     30.055646
# 4                01. Norte      12193        42092     28.967500
# 2             13. Oriental      12864        44662     28.803009
# 0        03. San Francisco      15219        54183     28.088146
# 15        07. La Ciudadela       3092        15045     20.551678
# 10        02. Nor Oriental       4494        28459     15.791138
# 9         09. La Pedregosa       4868        32299     15.071674
# 13       08. Sur Occidente       3307        22936     14.418382
# 11                 11. Sur       4339        33404     12.989462
# 16   16. Lagos del Cacique       3077        26723     11.514426
# 12               17. Mutis       4063        52290      7.770128

# %%
plt.figure(figsize=(20,10))
plt.pie(d_comunas['TASA_DELITOS'], labels=d_comunas['NOM_COMUNAS'], autopct="%0.1f %%")
plt.show()

# %%
#Obtenemos cada arma y creamos su respectivo diccionario
armas_medios=pd.unique(d['ARMAS_MEDIOS'])
armas_medios=sorted(armas_medios)
dic_armas_medios={}
for i in range(len(armas_medios)):
  dic_armas_medios[armas_medios[i]]=i
print("\nArmas por individual:",dic_armas_medios)

#Obtenemos cada barrio y creamos su respectivo diccionario
barrios_hecho=pd.unique(d['BARRIOS_HECHO'])
barrios_hecho=sorted(barrios_hecho)
dic_barrios_hecho={}
for i in range(len(barrios_hecho)):
  dic_barrios_hecho[barrios_hecho[i]]=i+1
print("\nBarrios por individual:",dic_barrios_hecho)

#Obtenemos cada dia de la semana y creamos su respectivo diccionario
dia_semana=pd.unique(d['DIA_SEMANA'])
dia_semana=sorted(dia_semana)
dic_dia_semana={}
for i in range(len(dia_semana)):
  dic_dia_semana[dia_semana[i]]=i+1
print("\nDia semana por individual:",dic_dia_semana)

#Obtenemos cada comuna y creamos su respectivo diccionario

dic_nom_comuna={}
for i in range(len(nom_comuna)):
  dic_nom_comuna[nom_comuna[i]]=i+1
print("\nComunas por individual:",dic_nom_comuna)

#Obtenemos cada conducta o definicion del delito y creamos su respectivo diccionario
conducta=pd.unique(d['CONDUCTA'])
conducta=sorted(conducta)
dic_conducta={}
for i in range(len(conducta)):
  dic_conducta[conducta[i]]=i+1
print("\nConductas por individual:",dic_conducta)

#Obtenemos cada clasificacion de delito y creamos su respectivo diccionario
clasificaciones_delito=pd.unique(d['CLASIFICACIONES_DELITO'])
clasificaciones_delito=sorted(clasificaciones_delito)
dic_clasificaciones_delito={}
for i in range(len(clasificaciones_delito)):
  dic_clasificaciones_delito[clasificaciones_delito[i]]=i+1
print("\nClasificaciones de delitos por individual:",dic_clasificaciones_delito)

#Obtenemos cada curso de vida y creamos su respectivo diccionario
curso_de_vida=pd.unique(d['CURSO_DE_VIDA'])
curso_de_vida=sorted(curso_de_vida)
dic_curso_de_vida={}
for i in range(len(curso_de_vida)):
  dic_curso_de_vida[curso_de_vida[i]]=i
print("\nCursos de vida por individual:",dic_curso_de_vida)

#Obtenemos cada movil del agresor y creamos su respectivo diccionario
movil_agresor=pd.unique(d['MOVIL_AGRESOR'])
movil_agresor=sorted(movil_agresor)
dic_movil_agresor={}
for i in range(len(movil_agresor)):
  dic_movil_agresor[movil_agresor[i]]=i+1
print("\nMovil del agresor por individual:",dic_movil_agresor)

#Obtenemos cada movil de la victima y creamos su respectivo diccionario
movil_victima=pd.unique(d['MOVIL_VICTIMA'])
movil_victima=sorted(movil_victima)
dic_movil_victima={}
for i in range(len(movil_victima)):
  dic_movil_victima[movil_victima[i]]=i+1
print("\nMovil de la victima por individual:",dic_movil_victima)

#Numerando los nombres de cada comuna y otras caractristicas

for i in range(len(armas_medios)):
  d.loc[d.ARMAS_MEDIOS==armas_medios[i],'ARMAS_MEDIOS']=i

for i in range(len(barrios_hecho)):
  d.loc[d.BARRIOS_HECHO==barrios_hecho[i],'BARRIOS_HECHO']=i+1

for i in range(len(dia_semana)):
  d.loc[d.DIA_SEMANA==dia_semana[i],'DIA_SEMANA']=i+1

for i in range(len(nom_comuna)):
  d.loc[d.NOM_COMUNA==nom_comuna[i],'NOM_COMUNA']=i+1

for i in range(len(conducta)):
  d.loc[d.CONDUCTA==conducta[i],'CONDUCTA']=i

for i in range(len(clasificaciones_delito)):
  d.loc[d.CLASIFICACIONES_DELITO==clasificaciones_delito[i],'CLASIFICACIONES_DELITO']=i

for i in range(len(movil_agresor)):
  d.loc[d.MOVIL_AGRESOR==movil_agresor[i],'MOVIL_AGRESOR']=i+1

for i in range(len(movil_victima)):
  d.loc[d.MOVIL_VICTIMA==movil_victima[i],'MOVIL_VICTIMA']=i+1
# Out:
# Armas por individual: {'ACIDO': 0, 'AGUA CALIENTE': 1, 'ARMA BLANCA / CORTOPUNZANTE': 2, 'ARMA DE FUEGO': 3, 'ARMA TRAUMATICA': 4, 'ARTEFACTO EXPLOSIVO/CARGA DINAMITA': 5, 'ARTEFACTO INCENDIARIO': 6, 'BICICLETA': 7, 'BOLSA PLASTICA': 8, 'CARRO BOMBA': 9, 'CARTA EXTORSIVA': 10, 'CINTAS/CINTURON': 11, 'COMBUSTIBLE': 12, 'CONTUNDENTES': 13, 'CORTANTES': 14, 'CORTOPUNZANTES': 15, 'CUCHILLA': 16, 'CUERDA/SOGA/CADENA': 17, 'DIRECTA': 18, 'ESCOPOLAMINA': 19, 'GASES': 20, 'GRANADA DE MANO': 21, 'JERINGA': 22, 'LICOR ADULTERADO': 23, 'LLAMADA TELEFONICA': 24, 'LLAVE MAESTRA': 25, 'MEDICAMENTOS': 26, 'MIXTA': 27, 'MOTO': 28, 'No Reporta': 29, 'PALANCAS': 30, 'PAPA EXPLOSIVA': 31, 'PERRO': 32, 'POLVORA(FUEGOS PIROTECNICOS)': 33, 'PRENDAS DE VESTIR': 34, 'PUNZANTES': 35, 'QUIMICOS': 36, 'REDES SOCIALES': 37, 'SIN EMPLEO DE ARMAS': 38, 'SUSTANCIAS TOXICAS': 39, 'VEHICULO': 40, 'VENENO': 41}
#
# Barrios por individual: {'12 DE OCTUBRE': 1, '13 DE JUNIO': 2, '20 DE JULIO': 3, '23 DE JUNIO': 4, '5 DE ENERO': 5, 'ACACIAS': 6, 'AFRICA': 7, 'ALARCON': 8, 'ALBANIA': 9, 'ALFONSO LOPEZ': 10, 'ALTO VIENTO I': 11, 'ALTOS DE CAÑAVERAL I': 12, 'ALTOS DEL CACIQUE': 13, 'ALTOS DEL KENNEDY': 14, 'ALTOS DEL PROGRESO': 15, 'ALVAREZ': 16, 'ANILLO VIAL': 17, 'ANTIGUA COLOMBIA': 18, 'ANTIGUO CAMPESTRE': 19, 'ANTIGUO COLOMBIA': 20, 'ANTONIA SANTOS': 21, 'ANTONIA SANTOS SUR': 22, 'ASENTAMIENTO SERVIUNON': 23, 'ASENTAMIENTO SERVUNION': 24, 'ASTURIAS': 25, 'AUTOPISTA P/CUESTA - F/BLANCA.': 26, 'BALCON DEL LAGO': 27, 'BALCON DEL TEJAR': 28, 'BALCONES DEL KENNEDY': 29, 'BALCONES DEL SUR': 30, 'BARRIO NUEVO': 31, 'BAVARIA': 32, 'BETANIA': 33, 'BOLARQUI': 34, 'BOLIVAR': 35, 'BONANZA CAMPESTRE (COLORADOS)': 36, 'BOSCONIA': 37, 'BOSQUE NORTE': 38, 'BOULEVAR DEL CACIQUE': 39, 'BRISAS DEL PALMAR': 40, 'BRISAS DEL PARAISO': 41, 'BUCARAMANGA': 42, 'BUENAVISTA': 43, 'BUENOS AIRES': 44, 'BULEVAR DEL CACIQUE': 45, 'C.R. SERREZUELA': 46, 'C.R. SOLERI': 47, 'CABECERA DEL LLANO': 48, 'CACIQUE CONDOMINIO': 49, 'CACIQUE IMPERIAL': 50, 'CACIQUE IPANA': 51, 'CAFE MADRID': 52, 'CALDAS': 53, 'CALLE REAL': 54, 'CAMILO TORRES': 55, 'CAMPESTRE NORTE (COLORADOS)': 56, 'CAMPO HERMOSO': 57, 'CAMPO MADRID': 58, 'CAMPO VALDES 1  C-4': 59, 'CANDILES': 60, 'CARLOS PIZARRO': 61, 'CARRASCO': 62, 'CENFER': 63, 'CENTAUROS': 64, 'CENTRAL DE ABASTOS': 65, 'CENTRO': 66, 'CHAPINERO': 67, 'CHIMITA': 68, 'CHORRERAS DE DON JUAN': 69, 'CIUDAD METROPOLITANA': 70, 'CIUDAD VENECIA': 71, 'CIUDADELA REAL DE MINAS': 72, 'CLAVERIANO': 73, 'COLORADOS': 74, 'COMUNEROS': 75, 'CONDADO CAMPESTRE': 76, 'CONDADO DE GIBRALTAR': 77, 'CONUCOS': 78, 'CORDONCILLO I': 79, 'CORDONCILLO II': 80, 'Chapinero': 81, 'DANGOND': 82, 'DELICIAS ALTAS': 83, 'DIAMANTE I': 84, 'DIAMANTE II': 85, 'DIVINO NIÑO (COLORADOS)': 86, 'DON BOSCO': 87, 'EL BOSQUESITO': 88, 'EL CINAL': 89, 'EL CRISTAL': 90, 'EL DIVISO': 91, 'EL DORADO': 92, 'EL FONCE': 93, 'EL JARDIN': 94, 'EL PABLON': 95, 'EL PABLON ( LA TORRE )': 96, 'EL PABLON ( VILLA LINA )': 97, 'EL PABLON ( VILLA PATRICIA )': 98, 'EL PALENQUE': 99, 'EL PORVENIR': 100, 'EL PRADO': 101, 'EL RETIRO': 102, 'EL ROCIO': 103, 'EL ROSAL': 104, 'EL TEJAR': 105, 'EL UVO': 106, 'ESPAÑA': 107, 'ESPERANZA I': 108, 'ESPERANZA II': 109, 'ESPERANZA III': 110, 'El Tejar': 111, 'FONTANA': 112, 'GAITAN': 113, 'GALAN': 114, 'GALLINERAL': 115, 'GARCIA ROVIRA': 116, 'GIRARDOT': 117, 'GOMEZ NIÑO': 118, 'GRANADA': 119, 'GRANJAS DE JULIO RINCON': 120, 'GRANJAS DE PROVENZA': 121, 'GRANJAS RIGAN': 122, 'GUADUALES': 123, 'GUAYACANES': 124, 'HACIENDA DEL CACIQUE': 125, 'HACIENDA SAN JUAN': 126, 'IGSABELAR': 127, 'INEM': 128, 'INV. CAMINOS DE PAZ': 129, 'INV. CARLOS PIZARRO': 130, 'INV. CLUB CHIMITA': 131, 'INV. DELICIAS': 132, 'INV. LOS CORRALES': 133, 'INV. LUZ DE ESPERANZA': 134, 'INV. LUZ DE SALVACION': 135, 'INV. NUEVO HORIZONTE': 136, 'INV. PAISAJES DEL NORTE': 137, 'INV. PUENTE NARIÑO': 138, 'INV. PUNTA BETIN': 139, 'INV. SERVUNION': 140, 'INV. TIBURONES': 141, 'INV. VILLAS DEL GIRARDOT': 142, 'INVASION GALLINERAL': 143, 'JARDINES DE ALTA GRACIA': 144, 'JARDINES DE COAVICONSA': 145, 'JOSE ANTONIO GALAN': 146, 'JOSE MARIA CORDOBA': 147, 'JUAN XXIII': 148, 'KENNEDY': 149, 'LA AURORA': 150, 'LA CAMPIÑA': 151, 'LA CEIBA': 152, 'LA CEMENTO': 153, 'LA CONCORDIA': 154, 'LA ESTRELLA': 155, 'LA FERIA': 156, 'LA FLORA': 157, 'LA FLORESTA': 158, 'LA FORTUNA': 159, 'LA GLORIA': 160, 'LA GRANJITA': 161, 'LA INDEPENDENCIA': 162, 'LA INMACULADA': 163, 'LA JOYA': 164, 'LA JUVENTUD': 165, 'LA LIBERTAD': 166, 'LA MALAÑA (URBANO)': 167, 'LA PALMA': 168, 'LA PEDREGOSA': 169, 'LA QUEBRADA': 170, 'LA SALLE': 171, 'LA UNIVERSIDAD': 172, 'LA VICTORIA': 173, 'LAGOS DEL CACIQUE': 174, 'LAS AMERICAS': 175, 'LAS CASITAS': 176, 'LAS COLINAS': 177, 'LAS DELICIAS': 178, 'LAS GRANJITAS B/GA': 179, 'LAS HAMACAS': 180, 'LAS MARGARITAS MUTIS': 181, 'LAURELES': 182, 'LIMONCITO': 183, 'LIZCANO I': 184, 'LIZCANO II': 185, 'LOS ACAS ...
#
# Dia semana por individual: {'01. Lunes': 1, '02. Martes': 2, '03. Miércoles': 3, '04. Jueves': 4, '05. Viernes': 5, '06. Sábado': 6, '07. Domingo': 7}
#
# Comunas por individual: {'01. Norte': 1, '02. Nor Oriental': 2, '03. San Francisco': 3, '04. Occidental': 4, '05. García Rovira': 5, '06. La Concordia': 6, '07. La Ciudadela': 7, '08. Sur Occidente': 8, '09. La Pedregosa': 9, '10. Provenza': 10, '11. Sur': 11, '12. Cabecera del Llano': 12, '13. Oriental': 13, '14. Morrorico': 14, '15. Centro': 15, '16. Lagos del Cacique': 16, '17. Mutis': 17}
#
# Conductas por individual: {'ACCESO CARNAL ABUSIVO CON MENOR DE 14 AÑOS': 1, 'ACCESO CARNAL ABUSIVO CON MENOR DE 14 AÑOS (CIRCUNSTANCIAS AGRAVACIÓN)': 2, 'ACCESO CARNAL O ACTO SEXUAL ABUSIVO': 3, 'ACCESO CARNAL O ACTO SEXUAL ABUSIVO CON INCAPAZ DE RESISTIR': 4, 'ACCESO CARNAL O ACTO SEXUAL ABUSIVO CON INCAPAZ DE RESISTIR (CIRCUNSTANCIAS AGRAVACIÓN': 5, 'ACCESO CARNAL O ACTO SEXUAL EN PERSONA PUESTA EN INCAPACIDAD DE RESISTIR': 6, 'ACCESO CARNAL O ACTO SEXUAL EN PERSONA PUESTA EN INCAPACIDAD DE RESISTIR  (CIRCUNSTANC': 7, 'ACCESO CARNAL VIOLENTO': 8, 'ACCESO CARNAL VIOLENTO (CIRCUNSTANCIAS AGRAVACIÓN)': 9, 'ACCIDENTAL': 10, 'ACCIDENTE TRANSITO BICICLETA': 11, 'ACCIDENTE TRANSITO MOTO': 12, 'ACCIDENTE TRANSITO PEATON': 13, 'ACCIDENTE TRANSITO VEHICULO': 14, 'ACOSO SEXUAL': 15, 'ACTO SEXUAL VIOLENTO': 16, 'ACTO SEXUAL VIOLENTO (CIRCUNSTANCIAS DE AGRAVACIÓN)': 17, 'ACTOS SEXUALES CON MENOR DE 14 AÑOS': 18, 'ACTOS SEXUALES CON MENOR DE 14 AÑOS (CIRCUNSTANCIAS DE AGRAVACIÓN)': 19, 'AMENAZA/CHANTAJE': 20, 'ASONADA': 21, 'ATRACO': 22, 'BALA PERDIDA': 23, 'BATALEO': 24, 'CAIDA': 25, 'CARCELARIA': 26, 'CIBER EXTORSION': 27, 'CLASICA': 28, 'CONSTREÑIMIENTO A LA PROSTITUCIÓN': 29, 'COSQUILLEO': 30, 'DELITOS SEXUALES': 31, 'DEMANDA DE EXPLOTACION SEXUAL COMERCIAL DE PERSONA MENOR DE 18 AÑOS DE EDAD': 32, 'DESCUELGUE DE MERCANCIA': 33, 'DEVOLUCION DE BIENES': 34, 'EMPLEO DE SUSTANCIAS TOXICAS': 35, 'ENFRENTAMIENTO ENTRE DELINCUENCIA COMUN': 36, 'ENFRENTAMIENTO POLICIA-DELINCUENCIA': 37, 'ENGAÑO': 38, 'ESTÍMULO A LA PROSTITUCIÓN DE MENORES': 39, 'EXTORSION': 40, 'EXTORSION GAO': 41, 'EXTORSION GDO': 42, 'EXTORSIÓN': 43, 'FACTOR DE OPORTUNIDAD': 44, 'FEMINICIDIO': 45, 'FLETEO': 46, 'FORCEJEO': 47, 'HALADO': 48, 'HOMICIDIO': 49, 'HOMICIDIO CULPOSO ( EN ACCIDENTE DE TRÁNSITO)': 50, 'HOMICIDIO INTENCIONAL O CON DOLO': 51, 'HOMICIDIOS COMUNES': 52, 'HOMICIDIOS EN A/T': 53, 'HURTO A AUTOMOTORES': 54, 'HURTO A CELULARES': 55, 'HURTO A COMERCIO': 56, 'HURTO A ENTIDADES COMERCIALES': 57, 'HURTO A ENTIDADES FINANCIERAS': 58, 'HURTO A MOTOCICLETAS': 59, 'HURTO A PERSONAS': 60, 'HURTO A PIRATERÍA TERRESTRE': 61, 'HURTO A RESIDENCIA': 62, 'HURTO A RESIDENCIAS': 63, 'HURTO ABIGEATO': 64, 'HURTO DE AUTOPARTES': 65, 'HURTO DE BICICLETAS': 66, 'HURTO RESIDENCIAS': 67, 'INCAPACIDAD PARA TRABAJAR O ENFERMEDAD': 68, 'INDETERMINADA': 69, 'INDUCCIÓN A LA PROSTITUCIÓN': 70, 'INTIMA': 71, 'LESIONES AL FETO': 72, 'LESIONES CULPOSAS': 73, 'LESIONES CULPOSAS ( EN ACCIDENTE DE TRANSITO )': 74, 'LESIONES EN A/T': 75, 'LESIONES PERSONALES': 76, 'LLAMADA MILLONARIA': 77, 'LLAVE MAESTRA': 78, 'MANIFESTACION': 79, 'MECHERO/HORMIGUEO': 80, 'NO REPORTA': 81, 'NO REPORTADA': 82, 'No Reporta': 83, 'PAQUETE CHILENO': 84, 'POR AMIGO / CONOCIDO': 85, 'POR ESTABLECER': 86, 'PORNOGRAFÍA CON MENORES': 87, 'PROXENETISMO CON MENOR DE EDAD': 88, 'QUEMADURAS': 89, 'RAPONAZO': 90, 'REDES SOCIALES': 91, 'RETENCION DINERO': 92, 'RIÑA ENTRE COMPAÑEROS PERMANENTES': 93, 'RIÑA ENTRE ESPOSOS': 94, 'RIÑA ENTRE HERMANOS': 95, 'RIÑA ENTRE HIJO-PADRE': 96, 'RIÑA O CONFLICTO ENTRE PANDILLAS': 97, 'RIÑAS': 98, 'ROMPIMIENTO DE VIDRIO': 99, 'ROMPIMIENTO PARED': 100, 'SECUESTRO EXTORSIVO': 101, 'SECUESTRO SIMPLE': 102, 'SICARIATO': 103, 'SIMULANDO NECESIDAD': 104, 'SUPL. COBRADOR-VENDEDOR': 105, 'SUPL. DIJIN-SIJIN': 106, 'SUPL. EJERCITO': 107, 'SUPL. OTRAS AUTORIDADES': 108, 'SUPL. SERVICIOS TECNICOS': 109, 'SUPUESTO GANADOR DE LOTERIA': 110, 'SUSTRACCION EN MOVIMIENTO': 111, 'TAQUILLAZO': 112, 'TIO / TIA': 113, 'USO SUSTANCIAS TOXICAS / ESCOPOLAMINADO': 114, 'UTILIZACIÓN O FACILITACIÓN DE MEDIOS DE COMUNICACIÓN PARA OFRECER SERVICIOS SEXUALES DE MENORES': 115, 'VANDALISMO': 116, 'VANDALISMO/SAQUEO': 117, 'VENTOSA': 118, 'VIOLACION CAJA FUERTE': 119, 'VIOLACION DE CERRADURA': 120, 'VIOLENCIA INTRAFAMILIAR': 121}
#
# Clasificaciones de delitos por individual: {'Lesiones fatales': 1, 'Lesiones no fatales': 2, 'NO REPORTA': 3, 'Violencia sexual': 4}
#
# Cursos de vida por individual: {'00. No reporta': 0, '01. Primera infancia': 1, '02. Infancia': 2, '03. Adolescencia': 3, '04. Jovenes': 4, '05. Adultez': 5, '06. Persona mayor': 6, 'No Reporta': 7}
#
# Movil del agresor por individual: {'A PIE': 1, 'BICICLETA': 2, 'CONDUCTOR BUS': 3, 'CONDUCTOR MOTOCICLETA': 4, 'CONDUCTOR TAXI': 5, 'CONDUCTOR VEHICULO': 6, 'NO REPORTA': 7, 'PASAJERO BUS': 8, 'PASAJERO METRO': 9, 'PASAJERO MOTOCICLETA': 10, 'PASAJERO TAXI': 11, 'PASAJERO VEHICULO': 12, 'TRIPULANTE AERONAVE': 13}
#
# Movil de la victima por individual: {'A PIE': 1, 'BICICLETA': 2, 'CONDUCTOR BUS': 3, 'CONDUCTOR MOTOCICLETA': 4, 'CONDUCTOR TAXI': 5, 'CONDUCTOR VEHICULO': 6, 'NO REPORTA': 7, 'PASAJERO AERONAVE': 8, 'PASAJERO BARCO': 9, 'PASAJERO BUS': 10, 'PASAJERO METRO': 11, 'PASAJERO MOTOCICLETA': 12, 'PASAJERO TAXI': 13, 'PASAJERO VEHICULO': 14}

# %%
data=d.loc[:,['EDAD','CONDUCTA']].values
print(data.shape)

kmeans = KMeans(n_clusters=4)
kmeans.fit(data)

plt.figure(figsize=(30, 10))
plt.subplot(131)
plt.scatter(data[:,0], data[:,1], cmap='rainbow')
plt.title('Datos por edad')
plt.xlabel('EDAD')
plt.ylabel('CONDUCTA')

plt.subplot(132)
plt.scatter(data[:,0], data[:,1], c=kmeans.labels_, cmap='rainbow')
plt.scatter(kmeans.cluster_centers_[:,0] ,kmeans.cluster_centers_[:,1], color='black')
plt.title('Metodo K-Means por edad')
plt.xlabel('EDAD')
plt.ylabel('CONDUCTA')

plt.subplot(133)
plt.title("K-means")
plt.scatter(d['ARMAS_MEDIOS'], d['CONDUCTA'], c=kmeans.labels_, cmap='rainbow')
plt.title('Metodo K-Means por medio de armas')
plt.xlabel('ARMAS_MEDIOS')
plt.ylabel('CONDUCTA')
# Out:
# (128108, 2)
# Text(0, 0.5, 'CONDUCTA')

# %%
data=d.loc[d.CLASIFICACIONES_DELITO==dic_clasificaciones_delito.get('Lesiones fatales')][['CONDUCTA','NOM_COMUNA']].values
print(data.shape)

kmeans = KMeans(n_clusters=4)
kmeans.fit(data)

plt.figure(figsize=(30, 10))
plt.subplot(121)
plt.scatter(data[:,0], data[:,1], cmap='rainbow')
plt.title('Datos por conducta o delito')
plt.xlabel('CONDUCTA')
plt.ylabel('NOM_COMUNA')

plt.subplot(122)
plt.scatter(data[:,0], data[:,1], c=kmeans.labels_, cmap='rainbow')
plt.scatter(kmeans.cluster_centers_[:,0] ,kmeans.cluster_centers_[:,1], color='black')
plt.title('Metodo K-Means por conducta delito')
plt.xlabel('CONDUCTA')
plt.ylabel('NOM_COMUNA')
# Out:
# (122166, 2)
# Text(0, 0.5, 'NOM_COMUNA')

# %%
#Porcentaje de delitos por comuna
def get_key(val):
    for key, value in dic_nom_comuna.items():
         if val == value:
             return key
p_c = np.empty(17)
for i in range(17):
  p_c[i]=np.mean(d['NOM_COMUNA']==(i+1))
  print("\nComuna ",get_key(i+1),":",p_c[i])
# Out:
# Comuna  01. Norte : 0.09517750647890842
#
# Comuna  02. Nor Oriental : 0.0350797764386299
#
# Comuna  03. San Francisco : 0.11879820151746963
#
# Comuna  04. Occidental : 0.05799793923876729
#
# Comuna  05. García Rovira : 0.0678802260592625
#
# Comuna  06. La Concordia : 0.07463234146189153
#
# Comuna  07. La Ciudadela : 0.02413588534673869
#
# Comuna  08. Sur Occidente : 0.025814156805195616
#
# Comuna  09. La Pedregosa : 0.03799918818496893
#
# Comuna  10. Provenza : 0.04930215130983233
#
# Comuna  11. Sur : 0.03386985980578887
#
# Comuna  12. Cabecera del Llano : 0.09534923658163424
#
# Comuna  13. Oriental : 0.10041527461204608
#
# Comuna  14. Morrorico : 0.024604240172354575
#
# Comuna  15. Centro : 0.10320979173822088
#
# Comuna  16. Lagos del Cacique : 0.024018796640334718
#
# Comuna  17. Mutis : 0.03171542760795579
